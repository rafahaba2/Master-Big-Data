# %% [markdown]
# # Lab assignment: SVMs in scikit-learn

# %% [markdown]
# ### Work performed by:
# #### Rafael Haba Díaz 79030459K
# #### Hugo Puerto Rosello 76884689J

# %% [markdown]
# In this assignment we will learn how to work with SVMs using the scikit-learn library. We will study in detail their cross-validation, pipelining, training times and kernel functions.

# %% [markdown]
# ## Guidelines

# %% [markdown]
# Throughout this notebook you will find empty cells that you will need to fill with your own code. Follow the instructions in the notebook and pay special attention to the following symbols.
#
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>You will need to solve a question by writing your own code or answer in the cell immediately below or in a different file, as instructed.</td></tr>
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>This is a hint or useful observation that can help you solve this assignment. You should pay attention to these hints to better understand the assignment.</td></tr>
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td>This is an advanced and voluntary exercise that can help you gain a deeper knowledge into the topic. Good luck!</td></tr>
# </table>
#
#
# During the assignment you will make use of several Python packages that might not be installed in your machine. If that is the case, you can install new Python packages with
#
#     conda install PACKAGENAME
#
# if you are using Python Anaconda. Else you should use
#
#     pip install PACKAGENAME
#
# You will need the following packages for this particular assignment. Make sure they are available before proceeding:
#
# * **numpy**
# * **matplotlib**
# * **scikit-learn**
#
# The following code will embed any plots into the notebook instead of generating a new window:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Lastly, if you need any help on the usage of a Python function you can place the writing cursor over its name and press Caps+Shift to produce a pop-out with related documentation. This will only work inside code cells.
#
# Let's go!

# %% [markdown]
# ## Synthetic dataset

# %% [markdown]
# For the first exercises of this assignment we will use the synthetic dataset generated by the following code:

# %%
import numpy as np
from sklearn.datasets import make_gaussian_quantiles
RND_STATE=np.random.RandomState(42)
# Build first cluster
X1, y1 = make_gaussian_quantiles(cov=2., n_samples=200, n_features=2, n_classes=2, random_state=RND_STATE)
# Build second cluster
X2, y2 = make_gaussian_quantiles(mean=(3, 3), cov=1.5, n_samples=300, n_features=2, n_classes=2, random_state=RND_STATE)
# Fuse them, scaling features differently and switching labels of y2
X = np.concatenate((X1, X2))
X[:, 0] *= 10
X[:, 1] /= 10
y = np.concatenate((y1, -y2+1))

# %% [markdown]
# The dataset consists of 500 points and consists of two Gaussian clusters. In each cluster points in its inner circle belong to one class, and those in the outer circle belong to the other class. Classes are switched in the second cluster so that it is more challenging to discriminate between both classes.
#
# If we plot these data we obtain the following:

# %%
from matplotlib.colors import ListedColormap
cm = ListedColormap(['#0000FF', '#FF0000'])    # blue, red
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cm)     
plt.show()

# %% [markdown]
# Once we have generated the data *(X, y)*, let us split them into a **training set** and a **test set**. There is a utility function in scikit-learn that does exactly this:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=RND_STATE)

# %% [markdown]
# Since *test_size=0.5*, both the training set and the test set will have 250 points each. The number of features is 2, as specified when invoking *make_gaussian_quantiles*:

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (250, 2)
# (250, 2)

# %% [markdown]
# ## Scikit-learn basics

# %% [markdown]
# Scikit-learn's models for **supervised learning** (SVMs are just one kind of such models) implement a common interface. The most important functions of this interface are the following:
#
# * **fit(X, y)**: trains the model, fitting it for input patterns *X* and outputs *y*.
# * **score(X, y)**: tests an already fitted model with additional data, returning the accuracy obtained (i.e., how similar the outputs given by the model are, compared to the true outputs *y*).
#
# Thus, all classifiers and regressors in scikit-learn have specific implementations for the above functions. The differences among models (e.g., the different parameters they use) are treated either during construction or internally within these functions.
#
# For the particular case of SVMs for classification, the implementing class is <a href=http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html>SVC</a>:

# %%
from sklearn.svm import SVC
SVC()
# Out:
# SVC()

# %% [markdown]
# As you can see, by default scikit-learn builds an SVM with the **RBF kernel**. We know that such an SVM needs 2 parameters: **C** (regularizer between model complexity and classification errors) and **gamma** (kernel width). These are set to 1 and to 'auto' respectively, where 'auto' stands for 1/d (that is, 1 divided by the number of features).
#
# If you want to create an instance of an SVM with other values for these parameters, you just specify them (the rest of options for the constructor can be safely ignored for now):

# %%
SVC(C=5, gamma=0.01)
# Out:
# SVC(C=5, gamma=0.01)

# %% [markdown]
# In practice it is difficult to know which values for *C* and *gamma* work best for a particular dataset. This is why it is common to try with a **grid** of values for both parameters, selecting the pair of values that result in the highest accuracy.
#
# The first step is selecting the parameter **ranges**. For this exercise, let us use these:

# %%
Cs = np.logspace(-2, 4, 7)
gammas = np.logspace(-4, 4, 9)

# %% [markdown]
# That is, *C* ranges from 0.01 to 10000, whereas *gamma* goes from 0.0001 to 10000, using powers of 10 as intermediate values.
#
# Recall that in order to avoid **overfitting**, we cannot use the test set for **tuning** these parameters. The following code keeps track of the accuracies obtained for the training set, selecting the best *C* and *gamma*:

# %%
# Accuracies
accs = np.zeros((len(Cs), len(gammas)))   # all accuracies (in matrix form)
best_acc = 0.0   # best accuracy
# For each C
for i, C in enumerate(Cs):
    # For each sigma
    for j, gamma in enumerate(gammas):
        # Create and train SVM
        svm = SVC(C=C, gamma=gamma).fit(X_train, y_train)
        # Keep track of accuracies and best params
        acc = svm.score(X_train, y_train)
        accs[i, j] = acc
        if acc > best_acc:
            best_C = C
            best_gamma = gamma
            best_acc = acc

# %% [markdown]
# It is illustrative to plot these accuracies in matrix form:

# %%
plt.imshow(accs, interpolation='nearest', cmap=plt.cm.hot)
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gammas)), gammas, rotation=45)
plt.yticks(np.arange(len(Cs)), Cs)
plt.title('Accuracies obtained')
plt.show()

# %% [markdown]
# The best parameters turn out to be:

# %%
print("Best C = " + str(best_C))
print("Best gamma = " + str(best_gamma))
# Out:
# Best C = 1.0
# Best gamma = 100.0

# %% [markdown]
# Which give a perfect accuracy on the training set:

# %%
print("Best accuracy on train = " + str(best_acc))
# Out:
# Best accuracy on train = 1.0

# %% [markdown]
# ## Cross-validation

# %% [markdown]
# Perfect accuracy may seem like great news. However, the performance on the test set is not so good:

# %%
best_model = SVC(C=best_C, gamma=best_gamma).fit(X_train, y_train)
best_model.score(X_test, y_test)
# Out:
# 0.628

# %% [markdown]
# This is a clear sign of overfitting on the training set. If you remember from the theory, ideally we should tune our model fitting it with the training set, but assessing performance on a separate set called **validation set**.
#
# However, usually there are not enough data to split them into separate training, validation and test sets. If that is the case, we can resort to **cross-validation**, which proceeds as follows:
# * The training set is partitioned into *k* subsets (called **folds**).
# * *k* different models are trained, using each of the *k* folds to assess performance and the remaining *k-1* folds to fit each model.
# * The best model is that whose average performance on the *k* folds is best.
#
# Programming all this is laborious. Fortunately, the team behind scikit-learn have a whole <a href=http://scikit-learn.org/stable/modules/cross_validation.html>cross-validation module</a>. In addition, the library also has a class specifically designed to perform grid search on the parameters you specify, which is called <a href=http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.GridSearchCV.html>GridSearchCV</a>:

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# As the documentation states, in order to build an instance of *GridSearchCV*, you will need to specify two objects:
# * An **estimator**, that is, the internal model that is optimized (in this case an *SVC* instance).
# * A **parameter grid**, a dictionary where you specify the parameter names and the ranges to perform the search on (these ranges were defined above).

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Use the code cell below to create a *GridSearchCV* object called *gs* with the SVM as estimator and the range for *C* and *gamma* we defined above.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
params = {'gamma': gammas, 'C': Cs}
gs = GridSearchCV(estimator= SVC(),param_grid=params, verbose = 2, return_train_score=True)

# %% [markdown]
# GridSearchCV is implemented as well as a model, so its fit(X, y) method is the one that performs the grid search, doing cross-validation under the hood.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Call the fit method on your *gs* object to perform the grid search on the training set. Do not worry if it takes some time to complete.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# If you build your *GridSearchCV* object above with *verbose=1* you will see a trace of how the cross-validation process is going. For more details, set *verbose=2*. If your PC has several processors you can speed up the whole process by setting *n_jobs* accordingly.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# [CV] END ...............................C=0.01, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=0.01, gamma=0.001; total time=   0.0s
# [CV] END ................................C=0.01, gamma=0.001; total time=   0.0s
# [CV] END ................................C=0.01, gamma=0.001; total time=   0.0s
# [CV] END ................................C=0.01, gamma=0.001; total time=   0.0s
# [CV] END ................................C=0.01, gamma=0.001; total time=   0.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=   0.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=   0.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=   0.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=   0.0s
# [CV] END .................................C=0.01, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=0.01, gamma=1.0; total time=   0.0s
# [CV] END .................................C=0.01, gamma=10.0; total time=   0.0s
# [CV] END .................................C=0.01, gamma=10.0; total time=   0.0s
# [CV] END .................................C=0.01, gamma=10.0; total time=   0.0s
# [CV] END .................................C=0.01, gamma=10.0; total time=   0.0s
# [CV] END .................................C=0.01, gamma=10.0; total time=   0.0s
# [CV] END ................................C=0.01, gamma=100.0; total time=   0.0s
# [CV] END ................................C=0.01, gamma=100.0; total time=   0.0s
# [CV] END ................................C=0.01, gamma=100.0; total time=   0.0s
# [CV] END ................................C=0.01, gamma=100.0; total time=   0.0s
# [CV] END ................................C=0.01, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=0.01, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=0.01, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=0.01, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=0.01, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=0.01, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=0.01, gamma=10000.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=0.1, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=0.1, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=0.1, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=0.1, gamma=0.0001; total time=   0.0s
# [CV] END .................................C=0.1, gamma=0.001; total time=   0.0s
# [CV] END .................................C=0.1, gamma=0.001; total time=   0.0s
# [CV] END .................................C=0.1, gamma=0.001; total time=   0.0s
# [CV] END .................................C=0.1, gamma=0.001; total time=   0.0s
# [CV] END .................................C=0.1, gamma=0.001; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=0.01; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=0.1, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=0.1, gamma=10.0; total time=   0.0s
# [CV] END .................................C=0.1, gamma=100.0; total time=   0.0s
# [CV] END .................................C=0.1, gamma=100.0; total time=   0.0s
# [CV] END .................................C=0.1, gamma=100.0; total time=   0.0s
# [CV] END .................................C=0.1, gamma=100.0; total time=   0.0s
# [CV] END .................................C=0.1, gamma=100.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=0.1, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=0.1, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=0.1, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=0.1, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=0.1, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=0.1, gamma=10000.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=1.0, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=1.0, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=1.0, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=1.0, gamma=0.0001; total time=   0.0s
# [CV] END .................................C=1.0, gamma=0.001; total time=   0.0s
# [CV] END .................................C=1.0, gamma=0.001; total time=   0.0s
# [CV] END .................................C=1.0, gamma=0.001; total time=   0.0s
# [CV] END .................................C=1.0, gamma=0.001; total time=   0.0s
# [CV] END .................................C=1.0, gamma=0.001; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=0.01; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=0.1; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=1.0; total time=   0.0s
# [CV] END ...................................C=1.0, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=10.0; total time=   0.0s
# [CV] END ..................................C=1.0, gamma=10.0; total time=   0.0s
# [CV] END .................................C=1.0, gamma=100.0; total time=   0.0s
# [CV] END .................................C=1.0, gamma=100.0; total time=   0.0s
# [CV] END .................................C=1.0, gamma=100.0; total time=   0.0s
# [CV] END .................................C=1.0, gamma=100.0; total time=   0.0s
# [CV] END .................................C=1.0, gamma=100.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=1000.0; total time=   0.0s
# [CV] END ................................C=1.0, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=1.0, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=1.0, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=1.0, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=1.0, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=1.0, gamma=10000.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=0.0001; total time=   0.0s
# [CV] END ................................C=10.0, gamma=0.001; total time=   0.0s
# [CV] END ................................C=10.0, gamma=0.001; total time=   0.0s
# [CV] END ................................C=10.0, gamma=0.001; total time=   0.0s
# [CV] END ................................C=10.0, gamma=0.001; total time=   0.0s
# [CV] END ................................C=10.0, gamma=0.001; total time=   0.0s
# [CV] END .................................C=10.0, gamma=0.01; total time=   0.0s
# [CV] END .................................C=10.0, gamma=0.01; total time=   0.0s
# [CV] END .................................C=10.0, gamma=0.01; total time=   0.0s
# [CV] END .................................C=10.0, gamma=0.01; total time=   0.0s
# [CV] END .................................C=10.0, gamma=0.01; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=0.1; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=1.0; total time=   0.0s
# [CV] END ..................................C=10.0, gamma=1.0; total time=   0.0s
# [CV] END .................................C=10.0, gamma=10.0; total time=   0.0s
# [CV] END .................................C=10.0, gamma=10.0; total time=   0.0s
# [CV] END .................................C=10.0, gamma=10.0; total time=   0.0s
# [CV] END .................................C=10.0, gamma=10.0; total time=   0.0s
# [CV] END .................................C=10.0, gamma=10.0; total time=   0.0s
# [CV] END ................................C=10.0, gamma=100.0; total time=   0.0s
# [CV] END ................................C=10.0, gamma=100.0; total time=   0.0s
# [CV] END ................................C=10.0, gamma=100.0; total time=   0.0s
# [CV] END ................................C=10.0, gamma=100.0; total time=   0.0s
# [CV] END ................................C=10.0, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=1000.0; total time=   0.0s
# [CV] END ...............................C=10.0, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=10.0, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=10.0, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=10.0, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=10.0, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=10.0, gamma=10000.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=0.0001; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=0.0001; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=0.0001; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=0.0001; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=0.0001; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=0.001; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=0.001; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=0.001; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=0.001; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=0.001; total time=   0.0s
# [CV] END ................................C=100.0, gamma=0.01; total time=   0.0s
# [CV] END ................................C=100.0, gamma=0.01; total time=   0.0s
# [CV] END ................................C=100.0, gamma=0.01; total time=   0.0s
# [CV] END ................................C=100.0, gamma=0.01; total time=   0.0s
# [CV] END ................................C=100.0, gamma=0.01; total time=   0.0s
# [CV] END .................................C=100.0, gamma=0.1; total time=   0.0s
# [CV] END .................................C=100.0, gamma=0.1; total time=   0.0s
# [CV] END .................................C=100.0, gamma=0.1; total time=   0.0s
# [CV] END .................................C=100.0, gamma=0.1; total time=   0.0s
# [CV] END .................................C=100.0, gamma=0.1; total time=   0.0s
# [CV] END .................................C=100.0, gamma=1.0; total time=   0.0s
# [CV] END .................................C=100.0, gamma=1.0; total time=   0.0s
# [CV] END .................................C=100.0, gamma=1.0; total time=   0.0s
# [CV] END .................................C=100.0, gamma=1.0; total time=   0.0s
# [CV] END .................................C=100.0, gamma=1.0; total time=   0.0s
# [CV] END ................................C=100.0, gamma=10.0; total time=   0.0s
# [CV] END ................................C=100.0, gamma=10.0; total time=   0.0s
# [CV] END ................................C=100.0, gamma=10.0; total time=   0.0s
# [CV] END ................................C=100.0, gamma=10.0; total time=   0.0s
# [CV] END ................................C=100.0, gamma=10.0; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=100.0; total time=   0.0s
# [CV] END ...............................C=100.0, gamma=100.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=1000.0; total time=   0.0s
# [CV] END ..............................C=100.0, gamma=1000.0; total time=   0.0s
# [CV] END .............................C=100.0, gamma=10000.0; total time=   0.0s
# [CV] END .............................C=100.0, gamma=10000.0; total time=   0.0s
# [CV] END .............................C=100.0, gamma=10000.0; total time=   0.0s
# [CV] END .............................C=100.0, gamma=10000.0; total time=   0.0s
# [CV] END .............................C=100.0, gamma=10000.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=0.0001; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=0.0001; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=0.0001; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=0.0001; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=0.0001; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=0.001; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=0.001; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=0.001; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=0.001; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=0.001; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=0.01; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=0.01; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=0.01; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=0.01; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=0.01; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=0.1; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=0.1; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=0.1; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=0.1; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=0.1; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=1.0; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=1.0; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=1.0; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=1.0; total time=   0.0s
# [CV] END ................................C=1000.0, gamma=1.0; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=10.0; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=10.0; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=10.0; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=10.0; total time=   0.0s
# [CV] END ...............................C=1000.0, gamma=10.0; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=100.0; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=100.0; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=100.0; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=100.0; total time=   0.0s
# [CV] END ..............................C=1000.0, gamma=100.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=1000.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=1000.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=1000.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=1000.0; total time=   0.0s
# [CV] END .............................C=1000.0, gamma=1000.0; total time=   0.0s
# [CV] END ............................C=1000.0, gamma=10000.0; total time=   0.0s
# [CV] END ............................C=1000.0, gamma=10000.0; total time=   0.0s
# [CV] END ............................C=1000.0, gamma=10000.0; total time=   0.0s
# [CV] END ............................C=1000.0, gamma=10000.0; total time=   0.0s
# [CV] END ............................C=1000.0, gamma=10000.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=0.0001; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=0.0001; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=0.0001; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=0.0001; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=0.0001; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=0.001; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=0.001; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=0.001; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=0.001; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=0.001; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=0.01; total time=   0.7s
# [CV] END ..............................C=10000.0, gamma=0.01; total time=   1.1s
# [CV] END ..............................C=10000.0, gamma=0.01; total time=   0.7s
# [CV] END ..............................C=10000.0, gamma=0.01; total time=   0.3s
# [CV] END ..............................C=10000.0, gamma=0.01; total time=   0.5s
# [CV] END ...............................C=10000.0, gamma=0.1; total time=   1.2s
# [CV] END ...............................C=10000.0, gamma=0.1; total time=   0.4s
# [CV] END ...............................C=10000.0, gamma=0.1; total time=   0.4s
# [CV] END ...............................C=10000.0, gamma=0.1; total time=   0.2s
# [CV] END ...............................C=10000.0, gamma=0.1; total time=   0.1s
# [CV] END ...............................C=10000.0, gamma=1.0; total time=   0.0s
# [CV] END ...............................C=10000.0, gamma=1.0; total time=   0.0s
# [CV] END ...............................C=10000.0, gamma=1.0; total time=   0.0s
# [CV] END ...............................C=10000.0, gamma=1.0; total time=   0.0s
# [CV] END ...............................C=10000.0, gamma=1.0; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=10.0; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=10.0; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=10.0; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=10.0; total time=   0.0s
# [CV] END ..............................C=10000.0, gamma=10.0; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=100.0; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=100.0; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=100.0; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=100.0; total time=   0.0s
# [CV] END .............................C=10000.0, gamma=100.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=1000.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=1000.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=1000.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=1000.0; total time=   0.0s
# [CV] END ............................C=10000.0, gamma=1000.0; total time=   0.0s
# [CV] END ...........................C=10000.0, gamma=10000.0; total time=   0.0s
# [CV] END ...........................C=10000.0, gamma=10000.0; total time=   0.0s
# [CV] END ...........................C=10000.0, gamma=10000.0; total time=   0.0s
# [CV] END ...........................C=10000.0, gamma=10000.0; total time=   0.0s
# [CV] END ...........................C=10000.0, gamma=10000.0; total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]),
#                          'gamma': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              return_train_score=True, verbose=2)

# %% [markdown]
# Now that the grid search is complete, let us recover the results obtained. To keep things as before, we would like to overwrite the following variables:
# * *accs*: accurary matrix for the different (*C*, *gamma*) pairs.
# * *best_acc*: best accuracy.
# * *best_C*: best value for *C*.
# * *best_gamma*: best value for *gamma*.
# * *best_model*: fitted model with the best *C* and the best *gamma*.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Recover these variables from the fitted *gs* object. Check the *attributes* section in the <a href=http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.GridSearchCV.html>documentation</a>.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# You do not need to retrain *best_model* from *best_C* and *best_gamma*, it is available directly in the *best\_estimator\_* attribute (notice the final underscore). Think also about how to get the accuracies in matrix form from *grid\_scores\_*. Numpy's *reshape* function may come in handy.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
best_acc = gs.best_score_
print("Best accuracy: " + str(best_acc))

best_C = gs.best_estimator_.C
print("\nBest C: " + str(best_C))

best_gamma = gs.best_estimator_.gamma
print("\nBest gamma: " + str(best_gamma))

accs = gs.cv_results_['mean_test_score'].reshape(7,9)
print("\nAccuracy matrix: \n" + str(accs))
# Out:
# Best accuracy: 0.7559999999999999
#
# Best C: 10000.0
#
# Best gamma: 0.001
#
# Accuracy matrix:
# [[0.508 0.508 0.508 0.508 0.508 0.508 0.508 0.508 0.508]
#  [0.508 0.616 0.712 0.704 0.54  0.508 0.508 0.508 0.508]
#  [0.48  0.724 0.74  0.728 0.684 0.692 0.68  0.524 0.508]
#  [0.572 0.732 0.752 0.72  0.712 0.688 0.684 0.528 0.508]
#  [0.672 0.748 0.74  0.676 0.692 0.692 0.684 0.528 0.508]
#  [0.728 0.74  0.744 0.672 0.692 0.692 0.684 0.528 0.508]
#  [0.748 0.756 0.732 0.704 0.688 0.692 0.684 0.528 0.508]]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Replot the accuracies just retrieved. In what way is the resulting figure different from the previous one?
#  </td></tr>
# </table>

# %% [markdown]
# There are not combinations of c and gamma for an accuracy of 1.

# %%
plt.imshow(accs, interpolation='nearest', cmap=plt.cm.hot)
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gammas)), gammas, rotation=45)
plt.yticks(np.arange(len(Cs)), Cs)
plt.title('Accuracies obtained')
plt.show()

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Reprint the best parameters and their accuracy on training. Explain the changes you observe.
#  </td></tr>
# </table>

# %% [markdown]
# The best accuracy on training is 0.7559 and on test is 0.767 they are very close (due to KFold crossvalidation), best C and Best Gamma change from the example where we get the 1 in accuracy.

# %%
####### INSERT YOUR CODE HERE

best_index = gs.best_index_

best_C = gs.best_estimator_.C


accsTest = gs.cv_results_['mean_test_score'][best_index]
accsTrain = gs.cv_results_['mean_train_score'][best_index]

best_gamma = gs.best_estimator_.gamma
print("\nBest gamma: " + str(best_gamma))
print("\nBest C: " + str(best_C))
print("\nAccuracy Test: \n" + str(accsTest))
print("\nAccuracy Train: \n" + str(accsTrain))

accs = gs.cv_results_['mean_test_score'].reshape(7,9)
print("\nAccuracy matrix: \n" + str(accs))
# Out:
# Best gamma: 0.001
#
# Best C: 10000.0
#
# Accuracy Test:
# 0.7559999999999999
#
# Accuracy Train:
# 0.767
#
# Accuracy matrix:
# [[0.508 0.508 0.508 0.508 0.508 0.508 0.508 0.508 0.508]
#  [0.508 0.616 0.712 0.704 0.54  0.508 0.508 0.508 0.508]
#  [0.48  0.724 0.74  0.728 0.684 0.692 0.68  0.524 0.508]
#  [0.572 0.732 0.752 0.72  0.712 0.688 0.684 0.528 0.508]
#  [0.672 0.748 0.74  0.676 0.692 0.692 0.684 0.528 0.508]
#  [0.728 0.74  0.744 0.672 0.692 0.692 0.684 0.528 0.508]
#  [0.748 0.756 0.732 0.704 0.688 0.692 0.684 0.528 0.508]]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Recalculate the accuracy on test. Dit it improve?
#  </td></tr>
# </table>

# %% [markdown]
# Yes it did, the k-fold crossvalidation improved it.

# %%
####### INSERT YOUR CODE HERE
best_model = SVC(C=best_C, gamma=best_gamma).fit(X_train, y_train)
best_model.score(X_test, y_test)
# Out:
# 0.744

# %% [markdown]
# ## Pipelining

# %% [markdown]
# So far we have assumed that, once the data are loaded, they are ready to be fed to our model without any changes. If you inspect the code above, there is no change in the dataset since creation till it is fed to the *fit(X, y)* method (note that splitting the patterns in validation folds does not change the patterns themselves).
#
# In practice this will rarely be the case. The data usually need some kind of previous transformations, such as making them all be uniform. This is what is known as **preprocessing**. Combining these transformations with other processes like cross-validation is tricky, as one must make sure that the transformations take place in each of the validation folds, so that the models are only fitted with properly transformed data.
#
# Once more, we are lucky that scikit-learn makes this task very easy. The class that encapsulates all this is called <a href=http://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html>Pipeline</a>:

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# Conceptually, a pipeline is defined as a series of **transformers**, followed by one final step which must be an estimator. In the scikit-learn's jargon, this means that the class that takes the last step must implement the method *fit(X, y)*, whereas all the previous classes must implement a new method called *transform(X)* that makes some modification on the input data *X*. If those transformations are data-dependent and have to be learnt, they must also implement another method called *fit_transform(X, y)*.
#
# Scikit-learn hides this complexity by implementing Pipeline itself as a model as well. Thus, this class complies with the interface we saw in the previous section:
# * **fit(X, y)**: calls *fit_transform(X, y)* for all transformers, then calls *fit(X, y)* for the final estimator. This means that all transformations are successively learnt and applied before fitting the model with the properly transformed data.
# * **score(X, y)**: calls *transform(X)* for all transformers, then calls *score(X, y)* for the final estimator. The final model requires transformed data, and all the transformations have been learnt by *fit(X, y)*, so they can be now applied directly.
#
# As the <a href=http://scikit-learn.org/stable/modules/pipeline.html>usage guide</a> describes, in order to build an instance of <a href=http://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html>Pipeline</a> you will need to specify a list of **steps**, that is, the transformers and the final estimator you wish to chain. For internal reference, each of these steps must be identified by a name as well as by its class, so the steps are passed as a list of (name, class) pairs. Consider the following example:

# %%
Pipeline([('svm', SVC())])
# Out:
# Pipeline(steps=[('svm', SVC())])

# %% [markdown]
# Which builds a pipeline with just one estimator (the default SVM), named 'svm'.
#
# Obviously, a pipeline makes sense only when there is more than a single step. To keep things simple, here we will add just one previous step before the SVM, which performs **normalization to zero mean and unit variance**. This is carried out by the class <a href=http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html>StandardScaler</a>:

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# This normalization makes all features be in the same scale, preventing that some feature may have a bigger influence than others just because of the different original scales. If you go back to the dataset's plot, you can see that the scale of the first coordinate is much larger than the second one ([-40, +60] range compared to [-0.3, +0.6]). If we applied an RBF SVM to the data as they are, when computing the kernel function the second coordinate would be negligible compared to the first one.
#
# However, the figure makes clear that both features are equally important for correct classification, so normalization should improve accuracies considerably. Let us see if this is indeed the case.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Build a pipeline called *pl* with a *StandardScaler* followed by an SVM. Name both steps as you please.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
estimators= [('scale', StandardScaler()), ('svm', SVC())]
pl = Pipeline(estimators)

# %% [markdown]
# Performing grid search is trivial now, since *pl* is a valid estimator for the *GridSearchCV* object.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Rewrite the grid search for the pipeline. This should overwrite again the variables *accs*, *best_acc*, *best_C*, *best_gamma* and *best_model*.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Since the pipeline steps are named, the way to access parameters now is 'step\_\_parameter' (notice the double underscore). For example, in the pipeline above, we would access the *C* parameter with 'svm\_\_C'.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
params = {'svm__gamma': gammas, 'svm__C': Cs}
gs = GridSearchCV(estimator = pl,param_grid=params, verbose = 2, return_train_score=True)
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 63 candidates, totalling 315 fits
# [CV] END .....................svm__C=0.01, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=0.01, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=0.01, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=0.01, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=0.01, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=0.01, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=0.01, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=0.01, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=0.01, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=0.01, svm__gamma=10000.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=0.0001; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=0.001; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=0.01; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=0.1, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=0.1, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=0.1, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=0.1, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=0.1, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=0.1, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=0.1, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=0.1, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=0.1, svm__gamma=10000.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .........................svm__C=1.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ........................svm__C=1.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .......................svm__C=1.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ......................svm__C=1.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=1.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=1.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=1.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=1.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=1.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ........................svm__C=10.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .......................svm__C=10.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ......................svm__C=10.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .....................svm__C=10.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=10.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=10.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=10.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=10.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=10.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .......................svm__C=100.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ......................svm__C=100.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=100.0; total time=   0.0s
# [CV] END .....................svm__C=100.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ....................svm__C=100.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ...................svm__C=100.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ...................svm__C=100.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ...................svm__C=100.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ...................svm__C=100.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ...................svm__C=100.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ......................svm__C=1000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END .....................svm__C=1000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ....................svm__C=1000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ...................svm__C=1000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ..................svm__C=1000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ..................svm__C=1000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ..................svm__C=1000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ..................svm__C=1000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ..................svm__C=1000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=0.0001; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=0.001; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=0.01; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=0.1; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END .....................svm__C=10000.0, svm__gamma=1.0; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ....................svm__C=10000.0, svm__gamma=10.0; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ...................svm__C=10000.0, svm__gamma=100.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END ..................svm__C=10000.0, svm__gamma=1000.0; total time=   0.0s
# [CV] END .................svm__C=10000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .................svm__C=10000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .................svm__C=10000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .................svm__C=10000.0, svm__gamma=10000.0; total time=   0.0s
# [CV] END .................svm__C=10000.0, svm__gamma=10000.0; total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('svm', SVC())]),
#              param_grid={'svm__C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]),
#                          'svm__gamma': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              return_train_score=True, verbose=2)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Replot the new accuracies. Are they different from the ones without the scaler?
#  </td></tr>
# </table>

# %% [markdown]
# Yes they are, the scale of acuracies goes from 0.5 to 0.9, we get the bests accuracies using gamma = 1 and C > 1.

# %%
plt.imshow(accs, interpolation='nearest', cmap=plt.cm.hot)
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gammas)), gammas, rotation=45)
plt.yticks(np.arange(len(Cs)), Cs)
plt.title('Accuracies obtained')
plt.show()

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Reprint the best parameters and their accuracy both on training and test. How did they change? Are they better now?
#  </td></tr>
# </table>

# %% [markdown]
# Yes, they are better now. The reason is that we have normalized the features.

# %%
####### INSERT YOUR CODE HERE
best_index = gs.best_index_

best_C = gs.best_estimator_.steps[1][1].C
print("\nBest C: " + str(best_C))

accsTest = gs.cv_results_['mean_test_score'][best_index]
accsTrain = gs.cv_results_['mean_train_score'][best_index]

print("\nAccuracy Test: \n" + str(accsTest))
print("\nAccuracy Train: \n" + str(accsTrain))
# Out:
# Best C: 1000.0
#
# Accuracy Test:
# 0.916
#
# Accuracy Train:
# 0.982

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td>
# Accuracies do not tell you what the SVM is actually doing internally. Since the data are bidimensional, in this case we can plot what is going on. Write some code that calculates the SVM output (i.e., the distance to the hyperplane) for a mesh of points in the range of the inputs *X*. Your code should plot these distances, as well as the points *(X,y)* passed, using the color convention for the dataset: red for one class and blue for the other one. Explain with your own words the figure you obtain.
# </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# The distance to the hyperplane is computed by the SVC method **decision\_function(X)**, which is also part of the interface of scikit-learn's models. Your plot should look similar to the ones that appear in <a href=http://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html>this example</a>. Feel free to base your code on the one appearing in the example.
#  </td></tr>
# </table>

# %% [markdown]
# ## Training times

# %% [markdown]
# All the classes that scikit-learn provides for **non-linear SVMs** make use of **LIBSVM** internally. LIBSVM is regarded as the state-of-the-art piece of software for non-linear SVM training. It is based on the classical **SMO** algorithm.
#
# SVMs are robust and have a very sound mathematical foundation. However, their main drawback in practical use is that, even if we use well-devised software to train them, the complexity is at least quadratic in the number of samples *n*. In big O notation, this is stated as **0(n<sup>2</sup>)**. This precludes the use of non-linear SVMs for very large datasets.
#
# To illustrate this time growth, we will work with the *adult* dataset, available at the <a href=https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/>LIBSVM website</a>. There are 9 versions of this dataset with increasing training test sizes, ranging from roughly 1600 in the first one to more than 32000 in the last one. They have been downloaded for you in the *data* folder, under the names *adultX.svm*, where X ranges from 1 to 9.
#
# Let us load for now the smallest version (*adult1.svm*). These .svm files have a special format to save space in disk. Fortunately, scikit-learn has some special functions to load this kind of files:

# %%
from sklearn.datasets import load_svmlight_file, load_svmlight_files

# %% [markdown]
# As their name makes clear, the first function loads a single file, whereas the second one can load several ones. In the particular case of *adult1.svm*, we want to load also the test set *adult1_test.svm* for parameter tuning, so we can write:

# %%
X_train, y_train, X_test, y_test = load_svmlight_files(("./data/adult1.svm", "./data/adult1_test.svm"))
print(X_train.shape)
print(X_test.shape)
# Out:
# (1605, 123)
# (30956, 123)

# %% [markdown]
# As you can see, this dataset has 123 features. Grid search could take long, so here we will use **linear SVMs**. Recall that the default kernel function is RBF, so this has to be specified during construction of the SVC class:

# %%
SVC(kernel='linear')
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Thus, the *gamma* parameter will no longer be applicable, and the only parameter to tune is *C*. Let us use a narrower range now, as training tends to take a long time for large *C*:

# %%
Cs = np.logspace(-3, 2, 6)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Use the code of the previous section to tune a linear SVM on the *adult1* dataset.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# A pipeline with normalization is not necessary in this case, since all features of the dataset turn out to be binary and scales are not an issue. Thus, the estimator inside *GridSearchCV* should be just a linear SVM.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Since there is a single parameter *C* to optimize, *accs* should become now a vector instead of a matrix.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
params = {'kernel':['linear'],'C': Cs}
gs = GridSearchCV(estimator = SVC(),param_grid=params, verbose = 2, return_train_score=True)
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .............................C=0.001, kernel=linear; total time=   0.0s
# [CV] END .............................C=0.001, kernel=linear; total time=   0.0s
# [CV] END .............................C=0.001, kernel=linear; total time=   0.0s
# [CV] END .............................C=0.001, kernel=linear; total time=   0.0s
# [CV] END .............................C=0.001, kernel=linear; total time=   0.0s
# [CV] END ..............................C=0.01, kernel=linear; total time=   0.0s
# [CV] END ..............................C=0.01, kernel=linear; total time=   0.0s
# [CV] END ..............................C=0.01, kernel=linear; total time=   0.0s
# [CV] END ..............................C=0.01, kernel=linear; total time=   0.1s
# [CV] END ..............................C=0.01, kernel=linear; total time=   0.0s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.0s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.0s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.0s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.0s
# [CV] END ...............................C=0.1, kernel=linear; total time=   0.0s
# [CV] END ...............................C=1.0, kernel=linear; total time=   0.0s
# [CV] END ...............................C=1.0, kernel=linear; total time=   0.0s
# [CV] END ...............................C=1.0, kernel=linear; total time=   0.1s
# [CV] END ...............................C=1.0, kernel=linear; total time=   0.0s
# [CV] END ...............................C=1.0, kernel=linear; total time=   0.0s
# [CV] END ..............................C=10.0, kernel=linear; total time=   0.2s
# [CV] END ..............................C=10.0, kernel=linear; total time=   0.2s
# [CV] END ..............................C=10.0, kernel=linear; total time=   0.2s
# [CV] END ..............................C=10.0, kernel=linear; total time=   0.2s
# [CV] END ..............................C=10.0, kernel=linear; total time=   0.2s
# [CV] END .............................C=100.0, kernel=linear; total time=   3.2s
# [CV] END .............................C=100.0, kernel=linear; total time=   1.7s
# [CV] END .............................C=100.0, kernel=linear; total time=   1.7s
# [CV] END .............................C=100.0, kernel=linear; total time=   2.5s
# [CV] END .............................C=100.0, kernel=linear; total time=   2.7s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'kernel': ['linear']},
#              return_train_score=True, verbose=2)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Print the best *C* and its accuracy both on training and test. Verify that overfitting is not happening.
#  </td></tr>
# </table>

# %% [markdown]
# Accuracy from Test and Training are similar, no overfitting is happening

# %%
####### INSERT YOUR CODE HERE
best_index = gs.best_index_

best_C = gs.best_estimator_.C
print("\nBest C: " + str(best_C))

accsTest = gs.cv_results_['mean_test_score'][best_index]
accsTrain = gs.cv_results_['mean_train_score'][best_index]

print("\nAccuracy Test: \n" + str(accsTest))
print("\nAccuracy Train: \n" + str(accsTrain))
# Out:
# Best C: 0.1
#
# Accuracy Test:
# 0.8317757009345794
#
# Accuracy Train:
# 0.8481308411214952

# %% [markdown]
# We will use this value of *C* for all versions of the *adult* dataset. In order to measure execution times, Python has the native function *time*:

# %%
from time import time

# %% [markdown]
# To measure how many seconds it takes to execute some code, place that code between two calls to *time* and measure the difference:

# %%
t_start = time()
for i in range(1000000):
    pass    # do nothing
t_end = time()
t_end - t_start
# Out:
# 0.06699824333190918

# %% [markdown]
# One of the improvements of LIBSVM with respect to SMO is its **caching** strategy. For most real-life datasets, there are patterns that are ignored by LIBSVM since they do not influence the solution, whereas there are other patterns that are repeatedly optimized upon in several iterations. If we store in a cache the rows of the kernel matrix corresponding to these repeated patterns, we can save the time needed to recalculate them from scratch.
#
# Obviously, the larger the cache is, the more rows it is able to store and the bigger its time-saving potential is. This size is controlled by the *cache_size* parameter of *SVC*, which defaults to 200 MB unless specified otherwise on construction:

# %%
best_model
# Out:
# SVC(C=10000.0, gamma=0.001)

# %% [markdown]
# Let us try with these sizes:

# %%
caches = [100, 200, 500]

# %% [markdown]
# Our goal is to plot training time versus number of patterns, repeating the process for these 3 cache sizes and the increasingly large *adult* versions. There are 9 of these, but we will work with just the first 6:

# %%
num_adults = 6

# %% [markdown]
# For example, for the default cache of 200 MB, the training time of the smallest *adult* version (the one currently loaded) is:

# %%
t_start = time()
best_model.fit(X_train, y_train)
t_end = time()
t = t_end - t_start
print((len(y_train), t))
# Out:
# (3185, 3.1921401023864746)

# %% [markdown]
# But this is is just a single point of the plot we want. Your task is to compute the training times for all combinations of cache sizes and *adult* versions, storing them in the following matrix:

# %%
times = np.zeros((num_adults, len(caches)))

# %% [markdown]
# Whereas the dataset sizes will be stored in the following vector:

# %%
sizes = np.zeros((num_adults, 1))

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Write the code that fills *times* and *sizes*.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# In order to minimize disk accesses, load each version of the *adult* dataset in an outer loop, and do the training for the different cache sizes in an inner loop.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Test sets are not needed, so it is enough to use *load_svmlight_file* to load the training sets.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
for i in range (1,7):
    X_train, y_train = load_svmlight_file("./data/adult"+str(i)+".svm")
    for c in range (len(caches)):
        t_start = time()
        params = {'C':Cs}
        svc =  SVC(cache_size = caches[c], C=10000.0, gamma=0.001)
        svc.fit(X_train, y_train)
        t_end = time()
        t = t_end - t_start
        times[i-1][c] = t
        sizes[i-1] =len(y_train)
print("Times: \n" + str(times))
print("\n Sizes: \n" + str(sizes))
# Out:
# Times:
# [[ 1.04617238  1.01252484  1.16013169]
#  [ 2.51822543  2.3428278   2.16088033]
#  [ 3.58688426  3.67245555  4.17558432]
#  [ 8.52549815  9.19543934  8.4581604 ]
#  [16.44926572 16.60322738 16.68136621]
#  [76.6914959  59.06112099 53.0133636 ]]
#
#  Sizes:
# [[ 1605.]
#  [ 2265.]
#  [ 3185.]
#  [ 4781.]
#  [ 6414.]
#  [11220.]]

# %% [markdown]
# At this point we have all the necessary information for plotting.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Use the code below to plots *times* versus *sizes*. What trend do you observe in the figure? Does this comply with the theoretical complexity? From what point does cache size begin to be relevant?
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# LIBSVM's complexity ranges from O(n<sup>2</sup>) to O(n<sup>3</sup>), depending on factors such as cache efficiency and the dataset itself. For example, the more features the dataset has, the longer training takes, since the complexity of computing the kernel function scales linearly with the number of features.
#  </td></tr>
# </table>

# %% [markdown]
# Until around 6000 patterns, training times are similar, but when we go up 7000 patterns, bigger cache sizes make faster training times. There is a point where bigger cache sizes make the differece in training times.

# %%
for i, c in enumerate(caches):
    plt.plot(sizes, times[:, i], label='Cache ' + str(c) + ' MB')
plt.xlabel('Number of patterns')
plt.ylabel('Training time (seconds)')
plt.legend(loc='best')
plt.title('Training times')
plt.show()

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td>
# Complete your study with the largest versions (*adult7*, *adult8* and *adult9*) and an additional cache size of 1000 MB. Replot the results. Is the previous trend confirmed?
#  </td></tr>
# </table>

# %%
num_adults = 3
caches = [100, 200, 500,1000]
sizes = np.zeros((num_adults, 1))
times = np.zeros((num_adults, len(caches)))

# %%
####### INSERT YOUR CODE HERE
for i in range (7,10):
    X_train, y_train = load_svmlight_file("./data/adult"+str(i)+".svm")
    for c in range (len(caches)):
        t_start = time()
        svc = SVC(cache_size = caches[c])
        svc.fit(X_train, y_train)
        t_end = time()
        t = t_end - t_start
        times[i-7][c] = t
        sizes[i-7] =len(y_train)
print("Times: \n" + str(times))
print("\n Sizes: \n" + str(sizes))
# Out:
# Times:
# [[ 36.74788666  33.96775126  33.29313493  33.19883943]
#  [ 69.25543165  84.82127452  85.85142946  86.03050518]
#  [177.08120847 139.5106802  137.65017295 155.50988626]]
#
#  Sizes:
# [[16100.]
#  [22696.]
#  [32561.]]

# %%
####### INSERT YOUR CODE HERE
for i, c in enumerate(caches):
    plt.plot(sizes, times[:, i], label='Cache ' + str(c) + ' MB')
plt.xlabel('Number of patterns')
plt.ylabel('Training time (seconds)')
plt.legend(loc='best')
plt.title('Training times')
plt.show()

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Because of time complexity, it may well be the case that these large datasets take a long time to train (minutes or even hours, depending on your computer). Use traces in your code to make sure everything is going fine.
#  </td></tr>
# </table>

# %% [markdown]
# This time growth always happens with non-linear SVMs, even if we use the best algorithms available. Note however that we have been experimenting with a linear SVM. For linear SVMs there are more efficient solvers for large datasets, based on techniques like coordinate gradient descent (LIBLINEAR) or stochastic gradient descent (Pegasos). Scikit-learn knows about this, and provides a specific implementation for a linear SVM that invokes LIBLINEAR called <a href=http://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html>LinearSVC</a>:

# %%
from sklearn.svm import LinearSVC
LinearSVC()
# Out:
# LinearSVC()

# %% [markdown]
# Note that there is no cache parameter now, since LIBLINEAR does not make use of a cache. On the other hand, LIBLINEAR is a flexible algorithm that can be used to train other models different than SVMs. To make it train an actual SVM, it must be constructed with *loss='hinge'*. Besides, since it has a random component, we will make use of *RND_STATE*. The rest of parameters are fine with their defaults:

# %%
LinearSVC(loss='hinge', random_state=RND_STATE)
# Out:
# LinearSVC(loss='hinge', random_state=RandomState(MT19937) at 0x2113E867D08)

# %% [markdown]
# Since this class takes a lot less time to train, we can now use all 9 versions of the *adult* dataset. As there is no cache now, we should reshape *times* to vector form:

# %%
num_adults = 9
times = np.zeros((num_adults, 1))
sizes = np.zeros((num_adults, 1))

# %%
caches
# Out:
# [100, 200, 500, 1000]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Rewrite the code that fills *times* and *sizes*, using now a *LinearSVC* instance instead of an *SVC* one.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
for i in range (1,10):
    X_train, y_train = load_svmlight_file("./data/adult"+str(i)+".svm")
    t_start = time()
    params = {'C':Cs}
    svc = LinearSVC(loss='hinge', random_state=RND_STATE)
    svc.fit(X_train, y_train)
    t_end = time()
    t = t_end - t_start
    times[i-1] = t
    sizes[i-1] =len(y_train)
print("Times: \n" + str(times))
print("\n Sizes: \n" + str(sizes))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Times:
# [[0.01199746]
#  [0.02955437]
#  [0.03900647]
#  [0.03799605]
#  [0.07099724]
#  [0.12600517]
#  [0.28700042]
#  [0.30352449]
#  [0.66653967]]
#
#  Sizes:
# [[ 1605.]
#  [ 2265.]
#  [ 3185.]
#  [ 4781.]
#  [ 6414.]
#  [11220.]
#  [16100.]
#  [22696.]
#  [32561.]]
# C:\Anaconda\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Plot the times obtained versus the training set sizes. Compare this figure with the one you got for the *SVC* class. What is the time complexity for *LinearSVC*?
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
plt.plot(sizes, times)
plt.xlabel('Number of patterns')
plt.ylabel('Training time (seconds)')
plt.legend(loc='best')
plt.title('Training times')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Custom kernels

# %% [markdown]
# To conclude this assignment, we will deal with custom kernels for non-numerical data.
#
# As we saw in the pipelining section, scikit-learn implements several transformers that help in adapting data to the specific needs of the different estimators. However, these are usually numerical transformations. What if the data we want to work with are non-numerical, such as images or texts? Good news: scikit-learn also provides transformer classes for these kinds of data.
#
# In this exercise, we will concentrate on texts. Texts are problematic not only because they are non-numeric, but also because they typically have different lengths, punctuation marks, uppercase and lowercase letters, etcetera. The most common strategy in <a href=http://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction>text preprocessing</a> is to transform a series of texts (**corpus**) into a **bag-of-words** representation. In plain language, this means:
#
# * Standardizing all texts in the corpus into a common form (e.g., lowercase with punctuation removed).
# * Splitting them in different units called **tokens** (e.g., words).
# * Counting how many times each token appears.
#
# Thus, each text will be transformed into a vector of length *d*, where *d* is the number of different tokens in the corpus. Its i-th element will be the number of times the i-th token appears in the text. This transformation is carried out by the <a href=http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html>CountVectorizer</a> class:

# %%
from sklearn.feature_extraction.text import CountVectorizer
CountVectorizer()
# Out:
# CountVectorizer()

# %% [markdown]
# By default we can see that it tokenizes texts into lowercase words. Let us illustrate how it works with a simple corpus with 3 short texts:

# %%
corpus = ['This is the first text.', 'This is the second text.', 'And yet another text: the third text.']

# %% [markdown]
# Fitting this corpus splits the different words, which are available in the *vocabulary\_* attribute:

# %%
cvec = CountVectorizer().fit(corpus)
cvec.vocabulary_
# Out:
# {'this': 8,
#  'is': 3,
#  'the': 6,
#  'first': 2,
#  'text': 5,
#  'second': 4,
#  'and': 0,
#  'yet': 9,
#  'another': 1,
#  'third': 7}

# %% [markdown]
# We can see that the i-th position of each word is determined by alphabetical order and that punctuation has been removed. The transformed texts will thus be:

# %%
X = cvec.transform(corpus)
X
# Out:
# <3x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 16 stored elements in Compressed Sparse Row format>

# %% [markdown]
# They are stored in a **sparse** matrix X, which only stores the words present. For example, the third text (that with index 2) is:

# %%
print(X[2,:])
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 5)	2
#   (0, 6)	1
#   (0, 7)	1
#   (0, 9)	1

# %% [markdown]
# That is, it has 2 occurrences of the 5-th word in the vocabulary ('text'), and 1 ocurrence of the 0-th, 1-st, 6-th, 7-th and 9-th words ('and', 'another', 'the', 'third' and 'yet'). Words not occurring have a count of 0 and they are not stored in *X* to save space. This sparse format may seem cumbersome for this little example, but it is very compact for extensive corpuses that yield large vocabularies. Usually each text (usually called **document**) will have only a few words from the whole vocabulary, so most of its features will be 0 and there is no need to store that.
#
# For example, the *20 newsgroups* dataset available in scikit-learn has 18000 documents. It can be loaded with the following utility function:

# %%
from sklearn.datasets import fetch_20newsgroups

# %% [markdown]
# The documents are pieces of news belonging to 20 categories. Here we will only use 2 of them (atheism and religion) in order to cast a binary classification problem. The source file is available in the *data* folder. Let us load the training data, which has 857 documents (480 talking about atheism, 377 about religion):

# %%
categories=['alt.atheism', 'talk.religion.misc']
data = fetch_20newsgroups(subset='train', categories=categories, data_home="./data", 
                          download_if_missing=True, random_state=RND_STATE)
X_train, y_train = data.data, data.target
print(data.target_names)
print(len(X_train))
print(sum(y_train == 0))
print(sum(y_train == 1))
# Out:
# ________________________________________________________________________________
# Cache loading failed
# ________________________________________________________________________________
# No module named 'sklearn.datasets.base'
# ['alt.atheism', 'talk.religion.misc']
# 857
# 480
# 377

# %% [markdown]
# A document looks like this:

# %%
X_train[0]
# Out:
# 'From: bil@okcforum.osrhe.edu (Bill Conner)\nSubject: Re: some thoughts.\nNntp-Posting-Host: okcforum.osrhe.edu\nOrganization: Okcforum Unix Users Group\nX-Newsreader: TIN [version 1.1 PL9]\nLines: 18\n\nKent Sandvik (sandvik@newton.apple.com) wrote:\n: In article <11838@vice.ICO.TEK.COM>, bobbe@vice.ICO.TEK.COM (Robert\n: Beauchaine) wrote:\n: >   Someone spank me if I\'m wrong, but didn\'t Lord, Liar, or Lunatic\n: >   originate with C.S. Lewis?  Who\'s this Campollo fellow anyway?\n\n: I do think so, and isn\'t there a clear connection with the "I do\n: believe, because it is absurd" notion by one of the original\n: Christians (Origen?).\n\nThere is a similar statement attributed to Anselm, "I believe so that\nI may understand". In both cases reason is somewhat less exalted than\nanyone posting here could accept, which means that neither statement\ncan be properly analysed in this venue.\n\nBill\n\n\n'

# %% [markdown]
# Note all the punctuation marks, whitespaces, linebreaks... Fortunately, *CountVectorizer* will take care of all that internally and will transform *X_train* into a numerical matrix suitable for an SVM. There are 3 possibilities for this SVM:
# * A linear SVM.
# * A non-linear SVM with some existing kernel (e.g., RBF).
# * A non-linear SVM with a custom kernel for this task.
#
# We covered the first 2 kinds of SVMs in the previous sections, so let us consider the third one. The class *SVC* allows to specify a user-defined function for the *kernel* attribute. The <a href=http://scikit-learn.org/stable/modules/svm.html#svm-kernels>documentation</a> specifies that your custom kernel must take as arguments 2 matrices of shape (n1, d), (n2, d) and return a kernel matrix of shape (n1, n2).
#
# Recall that a kernel measures similarity between patterns. Since our patterns will be word counts, we should do some operation that measures how similar two documents are, using their word-count vectors. A possibility that comes to mind is to count **how many words appear in both documents**. The following function calculates this:

# %%
def words_in_common(X1, X2):
    X1_bin = (X1 > 0).astype(np.int)     # binarize word counts in corpus X1: 1 = word appears, 0 = word does not appear
    X2_bin = (X2 > 0).astype(np.int)     # same for second corpus X2
    # Now, for two documents in binary vector form, the number of matching words is the sum of 1s in the same positions.
    # For example, [0, 1, 1, 0] and [1, 1, 1, 0] have two 1s in the same position (2nd and 3rd), so they have 2 words in common.
    # Observation: this is the same as the sum of the dot product of both vectors.
    # Thus, in matrix form we just have to transpose the second corpus, and call standard matrix multiplication.
    return X1_bin.dot(X2_bin.T)

# %% [markdown]
# Let us verify it works as expected:

# %%
print(words_in_common(X, X))
# Out:
#   (0, 2)	2
#   (0, 1)	4
#   (0, 0)	5
#   (1, 2)	2
#   (1, 1)	5
#   (1, 0)	4
#   (2, 1)	2
#   (2, 0)	2
#   (2, 2)	6

# %% [markdown]
# Obviously, each document has all words in common with itself. The first one has 4 words in common with the second one (they only differ in the words 'first' and 'second'). The remaining cells are also correct, and the resulting matrix is symmetric, as every kernel matrix should be.
#
# Now we are ready to try a pipeline with a *CountVectorizer* and an SVM with this custom kernel. We will use the same values for *C* than in the previous exercise.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Build the pipeline and optimize it with grid search, as you did in the previous sections.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
estimators= [('vectorizer',cvec), ('svm', SVC())]
pl = Pipeline(estimators)

params = {'svm__gamma': gammas, 'svm__C': Cs, 'svm__kernel':[words_in_common]}
gs = GridSearchCV(estimator = pl,param_grid=params, verbose = 2, return_train_score=True)
gs.fit(X_train, y_train)
clfBest = gs.best_estimator_
clfBest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END svm__C=0.001, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.001, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.001, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.001, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.001, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.001, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.001, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.001, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=0.001, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.001, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.001, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.001, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.001, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.001, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.01, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.01, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.01, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.01, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=0.01, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.01, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.01, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.01, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.01, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.01, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.01, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.01, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.1, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.1, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.3s
# [CV] END svm__C=0.1, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=0.1, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.1, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.3s
# [CV] END svm__C=0.1, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.1, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.1, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.1, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=0.1, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=0.1, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=0.1, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.1, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=0.1, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=0.1, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=0.1, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=0.1, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.5s
# [CV] END svm__C=1.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.3s
# [CV] END svm__C=1.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=1.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=1.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=1.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.3s
# [CV] END svm__C=1.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=1.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=1.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=1.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=1.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=10.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=10.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=10.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=10.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=10.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=10.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.2s
# [CV] END svm__C=10.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=10.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=10.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.5s
# [CV] END svm__C=10.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   2.2s
# [CV] END svm__C=10.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.5s
# [CV] END svm__C=10.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=10.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=10.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=10.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=10.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=10.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=10.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=10.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=100.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=100.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=100.0, svm__gamma=0.0001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=100.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.001, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.01, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.1s
# [CV] END svm__C=100.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=100.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=0.1, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=100.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=100.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=100.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=1.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.8s
# [CV] END svm__C=100.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.9s
# [CV] END svm__C=100.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=100.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   1.0s
# [CV] END svm__C=100.0, svm__gamma=1000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# [CV] END svm__C=100.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.7s
# [CV] END svm__C=100.0, svm__gamma=10000.0, svm__kernel=<function words_in_common at 0x00000211060FF1F8>; total time=   0.6s
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('svm',
#                  SVC(C=0.1, gamma=0.0001,
#                      kernel=<function words_in_common at 0x00000211060FF1F8>))])

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td>
# Report the value of *C* obtained, as well as the accuracies on training and test. How good are they?
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# You will need to load the test data. Load them like the training data.
#  </td></tr>
# </table>

# %% [markdown]
# Accuracy on training is 1, but in test is 0.80, there is overfitting, but accuracy on test is good.

# %%
####### INSERT YOUR CODE HERE
categories=['alt.atheism', 'talk.religion.misc']
data = fetch_20newsgroups(subset='test', categories=categories, data_home="./data", 
                          download_if_missing=True, random_state=RND_STATE)
X_test, y_test = data.data, data.target
print(data.target_names)
print(len(X_test))
print(sum(y_test == 0))
print(sum(y_test == 1))
# Out:
# ['alt.atheism', 'talk.religion.misc']
# 570
# 319
# 251

# %%
from sklearn.metrics import accuracy_score
best_C = gs.best_estimator_.steps[1][1].C
clfBest = gs.best_estimator_
y_pred = clfBest.predict(X_test)
accsTrain = gs.cv_results_['mean_train_score'][best_index]
print("C: ", best_C)
print("Accuracy Train:",accsTrain)
accsTest = accuracy_score(y_test, y_pred)
print("Accuracy Test: ", accsTest)
# Out:
# C:  0.1
# Accuracy Train: 1.0
# Accuracy Test:  0.8035087719298246

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td>
# One problem with the kernel *words_in_common* is that the information about how many times each word appears is lost. For example, if a given word W appears in a document D1 twice and in another document D2 just once, both documents are considered to match 100% for W. The same happens if that word appears twice both in D1' and D2'. In terms of similarity, though, it seems natural to consider that D1' and D2' are more similar for W than D1 and D2. A measure that takes this into account is the <a href=https://en.wikipedia.org/wiki/Cosine_similarity>cosine similarity</a>, defined as **u<sup>T</sup>v / (||u||*||v||)**, where **u** and **v** are the word-count vectors for both documents and **||·||** stands for the L2 norm. Define a function that implements cosine similarity, and tune the resulting pipeline. Can you obtain better results with this kernel?
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Recall that ||u|| = sqrt(u<sup>T</sup>u). Thus, you can implement this kernel in terms of numpy's *dot* function. Scikit-learn's function <a href=http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.normalize.html>normalize</a> can also be helpful.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td>
# Compare your results with the ones obtained by a linear SVM. Even if linear SVMs tend to give worse results, they have the advantage of the model's interpretability. Since the weight vector **w** does not depend on an unknown feature map, we can retrieve it after training. Moreover, because the decision function is **w·x + b** and one class is positive (y = +1) and the other is negative (y = -1), the components of **w** can be interpreted as the importance of the variables **x**: the more positive the i-th component of **w**, the more related is that variable to the positive class. Conversely, the more negative, the more related to the negative class. In this particular case, the features **x** are word counts, so the sign of **w** gives us how much a word indicates atheism (positive class) or religion (negative class). Once you have tuned your linear SVM, find the 10 most indicative words for each class. Do they make sense?
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# **w** is available in the *coef\_* attribute of the SVM. Since it is stored as a sparse matrix, you will need to transform it into a dense vector.
#  </td></tr>
# </table>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td>
# Once you retrieve **w**, you can find its largest and smallest components with numpy's *argsort* function. Note that the *CountVectorizer*'s *vocabulary_* attribute is in dictionary form, so you cannot find the words from their indices. Use instead the word list returned by the method *get_feature_names* of the *CountVectorizer* class.
# </td></tr>
# </table>

# %% [markdown]
# <center>
# ~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.<br>
#                           THIS IS THE END OF THE ASSIGNMENT<br>
# ~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.~.<br>
# </center>
